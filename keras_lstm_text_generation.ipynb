# %% [markdown]
# ## Generate text from Nietzsche's writings using LSTM in Keras
# * Author: Gao Yang
# * Note:
#     * 3 minutes per epoch on Intel i5 CPU
#     * Recommend: run on GPU (eg. Floydhub)
#     * At least 20 epochs are required, before generated text sounds coherent.
#     * If you use this on new data, make sure your corpus has at least ~100k characters, ~1M is better.

# %% [markdown]
# #### Setup the Keras enviorment

# %%
from __future__ import print_function, division
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
from keras.callbacks import LambdaCallback

import numpy as np
import io
import sys
import random

# %% [markdown]
# #### Get Nietzsche's writings and prepare character datasets

# %%
path = '/Users/Yang/Projects/keras-examples/nietzsche.txt'
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('Corpus length:',len(text))
# Out:
# Corpus length: 600902

# %%
chars = sorted(list(set(text))) # all characters appeared in text
print('character number in total:',len(chars))
char_indices = dict((c,i) for i, c in enumerate(chars))
indices_char = dict((i,c) for i, c in enumerate(chars))
# Out:
# character number in total: 60

# %%
# cut the text in sequences of characters, length = max_len
max_len = 40
step = 3
sentences = []
next_char = []

for i in range(0, len(text)-max_len, step): # i=0,3,6,9,...,until 600902-40=600862
    sentences.append(text[i:i+max_len]) # chop a piece of text
    next_char.append(text[i+max_len]) # the character that immediately follows that piece of text

print('total sequence number:',len(sentence))
# Out:
# total sequence number: 200288

# %%
x = np.zeros((len(sentences), max_len, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1 # label where a char appears in the right position in each sentence
    y[i, char_indices[next_char[i]]] = 1 # label where the first char of next sentence appears

# %% [markdown]
# ##### helper functions

# %%
def sample(prob_array, temp=1.0):
    
    "samples an index from a probability array"
    
    prob_array = np.asarray(prob_array).astype('float64')
    prob_array = np.log(prob_array) / temp
    exp_prob_array = np.exp(prob_array)
    prob_array = exp_prob_array / np.sum(exp_prob_array)
    probabilities = np.random.multinomial(1, prob_array, 1)
    
    return np.argmax(probabilities)

def on_epoch_end(epoch, logs):
    
    "prints generated text at end of each epoch"
    
    print()
    print('------ Generate text after epoch: {:02d}'.format(epoch))
    
    start_index = np.random.randint(0, len(text)-max_len-1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('diversity:{}'.format(diversity))
        
        generated = ''
        sentence = text[start_index:start_index+max_len]
        generated += sentence
        sys.stdout.write(generated)
        # or store into a file
        
        for i in range(400):
            x_prediction = np.zeros((1,max_len,len(chars)))
            for t, char in enumerate(sentence):
                x_prediction[0, t, char_indices[char]] = 1
                
            predictions = model.predict(x_prediction, verbose=0)[0]
            next_index = sample(predictions, diversity)
            next_char = indices_char[next_index]
            
            generated += next_char
            sentence = sentence[1:] + next_char
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# #### Build a LSTM model

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(max_len,len(chars)))) # input shape = shape of each slice of x
model.add(Dense(len(chars), activation='softmax'))

model.summary()

optimizer = RMSprop(lr=0.01)

model.compile(loss='categorical_crossentropy',
             optimizer=optimizer)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 128)               96768
# _________________________________________________________________
# dense_5 (Dense)              (None, 60)                7740
# =================================================================
# Total params: 104,508
# Trainable params: 104,508
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x,y,
         batch_size=128,
         epochs=20,
         callbacks=[print_callback])
# Out:
# Epoch 1/20
# 200288/200288 [==============================] - 167s 834us/step - loss: 1.5770
#
# ------ Generate text after epoch: 00
# diversity:0.2
# elief in "immediate certainties" is a morality of the soul and some of the soul and all the superious of the sense of the soul of the soul the serious of the same to the still the superious of the self-another and something the superioming of the superious of the still the soul of the soul of the superious of the soul and something of the still be some of the still the supposition of the still the soul of the soul the soul and all the s
# diversity:0.5
# elief in "immediate certainties" is a moral only from the contraction. an avily and extrint themsy the spiritual and seuratic only the morality of the sense of the spirit we place himself an its of the werves, and possible in the soul of the rest to the contract election that has his look the sciention as the belieful with one all the soul any would a such one the contrary of the soul and morality, and required in the soul of the last m
# diversity:1.0
# elief in "immediate certainties" is a morality of the bousd thich phisolopicg of scientizition, parenoc of mask life conoutse, the pursily, soollessed
# animal flowly, in themough. but "the philosophicy controlyed fordilical deccoicadilated tyaching, and gourture of all decaon, or therexisiim the syrrithes, speels of what lighinisc truth!
#
#
#
# 19. the whole when that
# this would dumily
# and make his dought, should soly for the god-greetest ha
# diversity:1.2
# elief in "immediate certainties" is a more nom lives anaterfuls
# say so flos" them formignly gre; oldifle,
# consideacic weice: on thesilte
# givives like the arcession thus
#
# in their
# send bathe conout distail, how dew
# can certain shinkly, belature: and rglusment, firr--and conmitely you. good
# sicleed the uscourage. they provesnes which iisious apsound;
# sides betariy philosopher
# fort accolosious
# rescants of
# cress gon
# with indivatnes or ! a g
# Epoch 2/20
# 200288/200288 [==============================] - 160s 801us/step - loss: 1.5209
#
# ------ Generate text after epoch: 01
# diversity:0.2
# rope, the one europe, whose soul pressess the strength, the present the strength of the present to the present the state of the experience to the present the present the present the strength, and a present the present the strength, the successible of the persons of the religion in the sprict the present the strength of the contitness and the present that the spirit of a personal and the strength for the distrust to the distrust to the s
# diversity:0.5
# rope, the one europe, whose soul pressess and pution to the religion of the difference them disgust the philosophical that have the presenting the presens themselves of the contrarys of a good which so much the philosophers" the philosophy of self for the contation of man is the press spiritually the distrust of the truth of the fact, in all possible of the discrestion in more discrestion in the "metiolity and a dispersons the persons t
# diversity:1.0
# rope, the one europe, whose soul pressest herto, proporting
# bod
# without perour life! a german in givertent
# circumstanded, in orders of the yind at to acquired exploite, genire with a weod costace has assudistact unconsequence is with truth and dear prutience and maxyn ligond and gain.--that nows that also suffect of religion of know congurd, the unfifaren, the suspicion it, was curiosous is commentribies has form
# to probnct obsiry to
# th
# diversity:1.2
# rope, the one europe, whose soul pressest, who error, as thrirg in deticter, usconue the eight explowagit" and chroliticiss, the pahe: but a lit of the "may "it goosnes uw herely ruen (logicy is frimidest, provelltge
# "i "more variative; fitny of uswonded courteble disposition accopeing
# then all shmacblizd,
# preciselywerrfority.--thranation cinsteve theory things
# almy also the celinty-exteal pasics and trooster,"--nauther
# result, justicos
# Epoch 3/20
# 200288/200288 [==============================] - 167s 835us/step - loss: 1.4875
#
# ------ Generate text after epoch: 02
# diversity:0.2
#  a principle out of what you yourselves
# and some stronger the stands and the stating the species of the sense of the stands and in the precisely the statisfines and the presence of the conditions of the stands and also the stands and the statisfing and stative interrogary and at the stands and in the stands and the stands the profound and the powerful the stronger and self and he say on the state of the static of the perhaps and wishes
# diversity:0.5
#  a principle out of what you yourselves
# different
# self and superiorical dealical same the so sances and artifferation of the powerful definitions of which is the precisely a cleard of those stands and the persons the conditions and hear only definitly stand and appearance and such the strongest determines the stronger the sense, and in his the persons, as mand in all as a thongs and he would have hitherto one is be no longer discover, i
# diversity:1.0
#  a principle out of what you yourselves
# in its
# spadliccousty. not as "nation? in ruling exprysetic of mishtyrit, lame" made vicially. his
# matteris, a right more human interpreties believe of bortaction of the eiticaps and liftly truthed
# that be stronity, if its desirtunorak live ever first the terribons of dend light the suffer of morality,
# them be littles will become elsemed through and
# willing themselves sport the languality of deflec
# diversity:1.2
#  a principle out of what you yourselves
# antirely, and a filning ride adounder interreds napric, short in distuilities, or in
# form noorasly "un=accirite his distrust the crow, autristw; such those hearthy us.
#
# no uncomming dis themselves some
# end arrict and
# alshamples is his moderner.--as a solitum spe do. "ime otherational deccands." ertists
# -freasonied once anoth is, itself uppracal perdapal lfood to be a
# risplancm of into
# definite spr
# Epoch 4/20
# 200288/200288 [==============================] - 169s 846us/step - loss: 1.4646
#
# ------ Generate text after epoch: 03
# diversity:0.2
# last possible, amid the flash lights of the state of the sense of the spirit of the state of the self-religious the same to the same and appearance of the same for in the state to the same of the state of the same to the same and the same to the same to be strength and profour of the profound the sances and the same to be a spirit of the sense of the subtlent and the spirit of the sublise in the same to be so believed to the sublisism o
# diversity:0.5
# last possible, amid the flash lights of every or interpretance of the great in manner in the subjut in the principle for the sublire the condition of human will and the princion
# profound of the considerance
# of many of the finally prosersitions which a profound the false and at the considerance of the saint of the manter for the sense of the princious of the sense of the progress of the word is a foreign feeling, and an experience in its
# diversity:1.0
# last possible, amid the flash lights of existence for and epochance in
# which has bour to believe,
# and the same believed of place of mottic iscentire of all-or institen bechoselfess of the
# stupide. whatever sufperior, the progress of hame do now and free psocration quals" of phyising this termiler" are. religious
# in the difference is always be tire in such deptianis. the paresy light with the heart in heart,
# allongent the author of asdap
# diversity:1.2
# last possible, amid the flash lights of the remanding and uttinged,"?
#
# eperiodment plasivilius himself--a cuetions is enemous rend-and of guidless, hove in unshuming ie, to
# smuggt from remain laws to say, anothratiquation wind thanscience?ness and freether limanh, dedices, not may know inferition of experiatifimunts its alse thoreuged in all sensuran be
# der faminaral and perplical farty
# and
# fectatione and to spoiners,
# which
# impulusising
# Epoch 5/20
# 200288/200288 [==============================] - 169s 842us/step - loss: 1.4464
#
# ------ Generate text after epoch: 04
# diversity:0.2
# enough,
# as anybody does who no longer feeling and such the strength, the suchience of the such a strong to the strongers of the sentiment the such the such a religion of the such a man as it is the sure of the such a child some present the such a conscience of the suchieme of the famer the suchieved and the states of the such a here the strongers of the such a strong to the stronger the stronger the suchiement and such a man is the such
# diversity:0.5
# enough,
# as anybody does who no longer feelings of the happiness of the in the german the strength, one must not in the strength of the sentiments and same to the inderemolation, would be in the great sceep and sure of the subject them what spectiles of the indainest function of the proves for the subtle in the assiment to the intellectual the basis of the prestion of his artives to himself or to himself there is the regard himself when
# diversity:1.0
# enough,
# as anybody does who no longer ferlony ourselves ground of timive
# which over formil idial paded upon
# ashing to prominence of the fello ones. it is him houry,
# every best
# spectime-sorion of reference, suchitys at was in let upon the caparilyd, whhir supperime and seems he neepernation and oprisins (on the preceret to foll
# staripr becomhalical lasting with the mofence thele persise--should maxe rater utter overtomment is so religion
# diversity:1.2
# enough,
# as anybody does who no longer fewloup: it woulde, no sagierce, a tutal epoisites to romany
# toll tast was norly: painss. attine, its
# degarbeadbolitnent or
# knowledge all namely, "grotts. the higher sual; he sagrous can not stupident requirency haine trads bef
# /Users/Yang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
# erence,
# the folly very indutaance,
# .
# ytal
# party is qualimintw] if theosaten of transely knesath"--demins sometrifications." bruge
# rock
# werist
# exception of "the suspicive at an
# Epoch 6/20
# 200288/200288 [==============================] - 153s 763us/step - loss: 1.4345
#
# ------ Generate text after epoch: 05
# diversity:0.2
# each this
# morality of mediocrity! it can not be strength of the sure of the profound that he seems to anything and the strength, and the stands the stands have nothing of the strength, and the profound, and what is the master of the strength, and the strength, and also the strength and profounds and such a sure of the pressions of the profound themselves of the strength and successived and such a surprising to the strength. the strength
# diversity:0.5
# each this
# morality of mediocrity! it can not be the great contract that we have not the look and contravied of life of the sure of the same subjuct of the such and that is now with the case in the "such a society, and should that a religionity, as an accurration, and the man and also be look also itself, and also his sight and an experience of his interpretations is spiritly one of the pain and desire and profunce of the successible tha
# diversity:1.0
# each this
# morality of mediocrity! it can be  my. a hum of the lad of ourselves? and they goffers he are living learned spirit to
# his conclunt merances us which means ress--he seaus other
# eeblebied has alwayswarlylus. not van origin of order good imploisned is nowadays
# in voluedhent and the wcogmy,
# surmivations and suffer of a perpecity far from ( for thought, sensual have putsore for the entare secreccions view of the tradit of ourselve
# diversity:1.2
# each this
# morality of mediocrity! it can live ought vensito radication, are again--"bad "itselmect absurdfulf! functemol, "condrantgn withour to good, seculideans, hass: rugh os valusible: to
# dangervade turic lacking. their
# gives.
#
#
# hind
# the perlencisionmence of humae hads without delication of moral, nood which ersergary) booge foorying erron, otheral depasing itseriotic
# is is,
# as intercriation even kind to the sance
# ares, which, cleys
# Epoch 7/20
# 200288/200288 [==============================] - 162s 807us/step - loss: 1.4236
#
# ------ Generate text after epoch: 06
# diversity:0.2
# x. such a being is not even thinkable for the state of the sure of the sure that the state of the sense and all the sure a man as the sure and superficianity of the sure of the sure as a man as the same as it is a man and a still a prover the state of the sure of the sure in the sure in the sure on the same to the sure of the sure in the superficiate that the sense and soul and experience of the strength of the sense of the sure of the
# diversity:0.5
# x. such a being is not even thinkable for a process its free nugn the sense,
# indeed, a positic, and of the fact and the express in the still a god that the decedite morality is a preservations and act that is a person to detorance and a short, in the former and morals the light or which is the objective in the state of delications of the endo souls, and species and superficiate in the sure of the consequence of the latter the disrate an
# diversity:1.0
# x. such a being is not even thinkable form of being both to be
# love is a bamiert in german, what is now it, to have mirston have not the sense and is of present, and this lies of ethine, and again: it has vingzing somengrous in nations, to gives, arded to year tegachring
# unasuch dygil
# am a certained doubliany rescounch faturations of repunomment of rownedy as the profoundans and will tacusaus, as it is will wish--it has nos does whether
# diversity:1.2
# x. such a being is not even thinkable forgeint to . i mansing, whilt !knowt. not  will bes, i hoinmly you
# only remain to
# we the know, at whan be the drantic appeoding dariftw! the fligner-nffirmer without acy im grugutionned
# tymants of philosophes and contection, with pehsence at with an approximate of the same somtxilitic
# work counter--and sensive, unled it, of
# necessary reseraxtis,--c agase," the
# bad agiaty.
#
# deeured in those inlighie
# Epoch 8/20
# 200288/200288 [==============================] - 164s 821us/step - loss: 1.4152
#
# ------ Generate text after epoch: 07
# diversity:0.2
# :--all this, however,
# is not vanity." the still be strength and some strength of the most strength and superiorical strength of the same the soul in moral and all the most self and will and in the most strength and contine as the consideration of the most strength and self and also the most strength and almost the more intellect of the belief of the same to the still a command. the strength and the strength and superiority of the soul o
# diversity:0.5
# :--all this, however,
# is not vanity." the statent and superior of the conceded and some indifacition of the comming, and there is also the thing in other to every any strict of the blended and maskers and in the entirary that the simply and not long, a same decisive or believents the greatered and interesting themselves for the heart that they had the strength of the will to the
# same
# discrise the strice of comprehens in the consideratio
# diversity:1.0
# :--all this, however,
# is not vanity." the spirit
# to even will almost reachy is also a wort, and
# most overed, plally
# the soul of feelings: profutence to
# fell
# the rel of the framilishment may have a keepts of all stonally upon the very worly with youth and conerstitness to anwiclity
# always he is tokally
# probebbar
# tantflication, reach.ly light toice under toffarunalmy, as
# estination and effent delocianism, accordence at to be existens.
#
#
# 1
# diversity:1.2
# :--all this, however,
# is not vanity." there in the cerseldsw?ing--in the
# kind of caum
# ke
# stmose faied--lone sufforum to, i only notha on oppreauat, it "the moruture of themor, hes evil.
#
# 1enoracies, efficcureces what, is althn medimnts delibes the side me).
#
#
# 11n towausse
# eimment in useurous
# problem homes ao; it is will "vidiaition, not some ows port is inclinaly
# and friends, grow deove,lyped
# the striltess.chose, everythagent."--i which
# Epoch 9/20
# 200288/200288 [==============================] - 168s 837us/step - loss: 1.4054
#
# ------ Generate text after epoch: 08
# diversity:0.2
# a tempo of the gallop, and of the best, and all the such a something and self--and the religious things and the strength of the surrens and self-proper of the sense of the same traditional sense of the strength of the surress of the super the same tender to the religious the will to the sense to the same and the self-basis of the spirit to the sense to the sense and the same to be the strength of the spirit of the strength and the spiri
# diversity:0.5
# a tempo of the gallop, and of the best, i have contention and most new spirits straged the former and the world. the themselves in the readiness of the constance of the higher one that is the feeling without the
# readiness of the will to him to mean namely the actions of the action of the spirits such on the surverce that is which an invilial of the expliction to be deplese its old conscience of the stronged in religious order for the su
# diversity:1.0
# a tempo of the gallop, and of the best, for sencely deepast thought also his manbiled to mold pain still haspains more scitdmite preservation thereupe our schopenhaule: the lat decation, or in every old
# gall unejoptivion of proportions perfores, a thiugie, in all a man; height
# in ue anything
# ane almive in the highe of the ways.
#
#
# 22. the hillome to get indebletay or an afily with the realwably scirish of giver i bringic that which withe
# diversity:1.2
# a tempo of the gallop, and of the best, fully
# fasicumed, esred, by semiliars specactions; why maxe a taste knows there me: lectines persaused thas they beliefchest hypivisiene profound, and while a proves sprels mew
# sacrited
# and
# abalowion unwill the moded, with the resplessubular high dance
# ashapain). very miraied"--in: philosophersjuved--the suspeipary time
# smin parfage upward his, gred casing",
# the will thles goerstous by an uprodedfu
# Epoch 10/20
# 200288/200288 [==============================] - 174s 870us/step - loss: 1.4009
#
# ------ Generate text after epoch: 09
# diversity:0.2
# oever has done this, has perhaps just the strength of the fashing the develop and soul the soul of the such a man are the sense and the sense and self-best in a consideration of the and sense and conscience of the super of the present to the sense and soul of the same discording to the or and the same nothing the such a man is a desire and soul in the present to the more and souls and desire to the sense of the present of the same astic
# diversity:0.5
# oever has done this, has perhaps just the amort of the former and looks of the evil open, and in the experience is in the happiness and make the morality in the significance that the said also into every problem of a contemplental conditions of the more spectful of the necessary and influence of a man in the free more which nothing of man in the sense and species elements of the the conflict and state of the conditions of life and the s
# diversity:1.0
# oever has done this, has perhaps just the fashs, self-pushancting
# thing looks of faver constitute origin
# as unim of which them is luxpute in the who, mo.
#
#
# nabuterish and the mankindswfellty too has takinuls as age on the ohing, it is truth ined in itself to beraceness, spile him higher intrend-belief and namiloid: to be untets of lood
# they have lather, toone of more envolun and
# soilsograd, impossible esulightlonable hear seem of thing
# diversity:1.2
# oever has done this, has perhaps just their wody;
# in rendershipther,
# brised knowmselebeny nof displaxuned, a soughty,
# yes: but which which festive better
# anyaming,w? phy, and herrder maken short, to a plasively a fynecity and
# soo body -add the rutogess bue feels
# thirgment and spiritually trop too (the
# nom from obliged
# uncale lehtn
# timidity for lateriled,
# such "by means of
# oldens,
# man great a veoder
# pressword
# to mewher itir, atopint. mor
# Epoch 11/20
# 200288/200288 [==============================] - 155s 776us/step - loss: 1.3950
#
# ------ Generate text after epoch: 10
# diversity:0.2
# ), to sweep away from ourselves altogether the most standard and sense of the sense of the sense of intellectually and sense, and the sense of the sense of the subject the sense of the sublimation of the sense of the freasones of the sense of the consequence of the present to the sense of the expression of the sense of the sense of the sense of the sense of the sense of the sense of the spirits of the sense of the sense of the sense of
# diversity:0.5
# ), to sweep away from ourselves altogether, for the far
# in the carry to the happiness of the desirable to the experienced of nature, the most consequence of the lacking of the soul, and desired that it is not amough of right and much the abscrivation in the standard to the most spirituality of the frence the staid and sensation of the world would not many compoldiness as something and delew to the sense and persons and life and carries
# diversity:1.0
# ), to sweep away from ourselves altogether fore those evil
# philosophy
# about the something and
# most fore--when any the gloral,
# uprabit, and unalu,
# defutes "supposedt--then in the goe's trisness you achieve are the stance which is knows us as i laughtarals." i justiced our worss to geliterate is woubs of the characue, in brought serious--nothing of more pain, to individual, the goalling still, and intentirtion of our emotious virtue: on
# diversity:1.2
# ), to sweep away from ourselves altogether pleatule or costion, was demintness for it are, of the healts--aveovious
# sube-hedpense "bory, lack." should say--in lavituedife of schoof that have, coal,
# and gradurity
# crumslenes of responsiciations of spate ourselve
# have
# people.
# perhaard-very resslvhe-by and
# nervocable: there even as many: waitg-idivent, by
# seren, darforment
# most wealness
# fors--sibour difficulty.
#
#
# 8o¤a
# man race-ons, inoncur:
# Epoch 12/20
# 200288/200288 [==============================] - 1204s 6ms/step - loss: 1.3898
#
# ------ Generate text after epoch: 11
# diversity:0.2
#  an
# experience) more than he loves another to the said of the proper to the sense of the most other of the sense of the said to be a strength of the strength and and some strengther to the sense of the present to the contradiction of the readily of the sense of the science of the sense of the profound in the sense of the sense of the surprise in the profound in the farce of the sense of the sure only the sense of the sense of the sure o
# diversity:0.5
#  an
# experience) more than he loves another to this secrets of the concerning to the readily of the experience of the world and designated to the spirit to commenced to which he who will not be as the same similaticism of the subjective inclinary is also we last man as if the have he world of the consequences to the goils, is the condition and in a man is the whole times for his production of the profound in the truth for his tempo at it
# diversity:1.0
#  an
# experience) more than he loves another cry and command--good in anaiving, to bad now
# that virtued in the virtue of denler, we fort nearly serious one of still
# blent of animility and created mededer to the greek nightmstice, as the mere to the old excesslidpess a much europey for
# the qualitions effect and dependentofic imperonce, something nature. but of his colition of common
# lived also, is dangerful, even an allow socholicible, in
# diversity:1.2
#  an
# experience) more than he loves another
# long "doinging will cases and been s. we groimly ineving of minsion not with self-hobks of the varl:--a tuve
# by mastikus tewarr"!t
# and age, religion in that knowledge (allosear syteluwmfull,
# to the may also have it! laugh, grows-mait is
# also crad in what "comeding yie under thord; all astress as the happ our swho, from they be pardo, or our pit constantly, is immorarh. this pommilam idar
# invalc
# Epoch 13/20
# 200288/200288 [==============================] - 173s 864us/step - loss: 1.3859
#
# ------ Generate text after epoch: 12
# diversity:0.2
# s, because it believed in oppositions
# of the soul and more the sense of the condition of the standards and the morality and the morality of the experience of the contemption of the strength of the power of the condition of the stand of a man is a soul and something and sometimes of the stand of the spirit of the strength of the self-destruments of the same too have and soul and something of the sense of a desting the soul of the strengt
# diversity:0.5
# s, because it believed in oppositions
# of
# the soul of the experience of the serious intelligence of such a persons of a pain of humanity of history of present of the standant the morality of the self-popstogation, to the experience of betrays historical one suffers the preservation, and rank to life
# on the sentiments, such a moral people and to an action of philosophers of the destination, the stupidition of the combesing things in the a
# diversity:1.0
# s, because it believed in oppositions
# of whichoveirce" of the
# posss
# ho
# literationish--in philosophied;
# sins, a questied accurtions
# value-ygenian himself fundament of the impondiol,", love and avims view of
# does the made of will
# sees
# dicalousefition, sows
# also sgetates 'stimate pevinical world
# to too himselves of a world: the o haffuntion.--fear origin that befute ot he german markess he life-pital; ows
# -or intirmus obligtionally nan goi
# diversity:1.2
# s, because it believed in oppositions
# of
# them specialice...
#
# 2 the replamm, in
# anti-knowt; of ignom of rapudically oftening ever whatever posit ouraze does-so, any is upor which is imany as to uight.
#
# weãr pivent
# doing imstent kindfiled uting-physicioys that impurary benezical ospidence,s. in thing a
# catwither generation of
# of
# ma guty--the heveace werethers owing tomay. disantying somese france. owingi ed than any moral"? a.
# one repeat
# Epoch 14/20
# 200288/200288 [==============================] - 169s 844us/step - loss: 1.3815
#
# ------ Generate text after epoch: 13
# diversity:0.2
#  present-day
# germans there is alternately the supposition of the superficial superficial and supposition and supposition of the principle of the supposition of the condition of the superficial and something of the sure has a subject and the superficial the standard and supposition of the same time and supposition and supposition of the subject and subject in the great the soul and supposition of the sure and in the spirit in the subject
# diversity:0.5
#  present-day
# germans there is alternately the condition of the spirit the sense the way may swere in the moral nature of his taste, in the moral heart of the virtue in his except the point of the point in a conscience of a desire of the soul of a comperhaple commonity of the degrain of the spirit to a scaie the feeling of the succession and said the belief which that in the superficiality of the general of an inclination of the treat of
# diversity:1.0
#  present-day
# germans there is alternateligurish as except the standards
# ruble a developing,
# unegoist absolutely and change for the virtues the
# time of the spiritual things" of "refrech being clume of tell discretive or almost now peoned worke can justic has believed is "evil in order they from philosopherable,
# as an invous philosopher itself been great wis, has constant man" full are themound that the civoltable his pommoriative new sch
# diversity:1.2
#  present-day
# germans there is alternately of our beneboled by a cry noid, chorate oving
# flamxkirk as suitayion
# chony, which mele ver--inshwhich in
# valuses of reductivelf_ modes altiaghato
# that it "trair as beeit superperioud alignes himxabdion, virclem guil as the remuitures
# but already more potively account
# in such misurpused this graded, nations friendful
# among in respectio judries and skhilled amaking-ghugigial after ihgh, does where
# Epoch 15/20
# 200288/200288 [==============================] - 159s 796us/step - loss: 1.3766
#
# ------ Generate text after epoch: 14
# diversity:0.2
#  mirror and self
# reflector, when the occasions and profound and something and the stronger to the stronger of the most superficially as the sense and such a distinguish of the stronger of the stronger to the spirit all the spirit, and the sense of the stronger the most still the first to the spirit to the stronger of the sense of the sense of the stronger of the superficially and something and proper the stronger and spiritual truth and
# diversity:0.5
#  mirror and self
# reflector, when the occasions itself without all the fashs, as the same mand to the general and the worthy was that it is perhaps without regard to them and extent and a personality, or and does not of the strengthy of the man to the most instincts that we fell in order to german something the good forms of which the arris approbce and delight, it was the spiritual truth
# and with the old that the batinage for the man is
# diversity:1.0
#  mirror and self
# reflector, when the occew known own call think, art, the way, allogian with an adfliation without for the
# continual actived
# have a she taste
# come,
# the point seems of own.--why with romages are happiness: it is forking fact, whoper, ranking, shortness of sufficiently discontitions, it is too tragicizue and cause has but reverest in such todominated itstorien is hindes now
# effect of truth," power, to philomosmer "the sele
# diversity:1.2
#  mirror and self
# reflector, when the occulieuse with the idenchy
# perraymenation of
# the livances
# "ma. for plator and more waling than
# perhaps
# phy, as the "something lookes the vice
# would not purithy of outsers himself as adnaticifle; ungeaso, ny is starts? music. it is good power,"
# that is goes rises-moral, arous
# id contitucufly look and insage aftiocs of
# they hip fell deplication. with the tasien a more period culys--that it seems to fl
# Epoch 16/20
# 200288/200288 [==============================] - 160s 799us/step - loss: 1.3772
#
# ------ Generate text after epoch: 15
# diversity:0.2
# f surprisingly
# when it can pose as "la religion that it is a sense of the strength, and also the sunly the strength, and the strength of the strength of the prompted the sublime and process of the compleessed to the sublime and sublime the superfluned the strength, and the strength, and the strength, and also a states of the sublime the superfection of the sublime and states of the strength of the present to the strength, the most the s
# diversity:0.5
# f surprisingly
# when it can pose as "la religion of the conscience and subtle
# for the destrument and subtlened to the very insignistic that he makes homes its possible to the contempt of the superficity of the standed a seem in the strength, the strongered of the corruption of the most "godness and an evil, really the most sense, and it is for the strength for the purpose of the comparenty of the spirit to the created the conduct of desi
# diversity:1.0
# f surprisingly
# when it can pose as "la rearily and lover? so arrange of which a sufficient. histarific otr-yise as com, superrible as hunder names, in other--who at an advist of done! it will be play. our century is all emotions and our even words postest
# to theard"; traik and more lains strengthe, thet we be art of
# reprovil of "trom decest self-persond, or, the wory when them every tently, the rent, as
# if the universal patted. for the
# diversity:1.2
# f surprisingly
# when it can pose as "la requition even intelligencr-treman under guidy unprecivation in it. whoe guining) for one of creatiz, in latter.
#
#
# 1h©a inner libore lightrighty some
# innoled
# almost heaving,orne. "the stores, a tals!
# !d re'mon high suvpous in their god-loat-fort in bood. happeness) in the philosopere of the but a generary, as transryd or justonly, without to alseringlow fall, longers to a
# noble stanestof and thoreq
# Epoch 17/20
# 200288/200288 [==============================] - 169s 845us/step - loss: 1.3743
#
# ------ Generate text after epoch: 16
# diversity:0.2
# s outcry when the problem of truthfulness of the standard of the standards the word to be all the standards of the most perhaps and the strive and free such a surfent and subtled to be a hand to be a superficied the person of the standard the plasion of the standard the states of the artistic which the state of the state of the strength and interpose in the consideration of the sentence of the strengthy and the most perhaps and the stat
# diversity:0.5
# s outcry when the problem of truthfulness of the sense of the feelings its
# them that have to the faith, it is it is one and himself and fashally to the powerful and the sighted of his interpose that the probable that he have been fred in this proversian
# interpresion things that pleasure in the most morality, and the most men that the standing that it is "christianity for the extent and the free successful and other be such and instance
# diversity:1.0
# s outcry when the problem of truthfulness errin
# which our path of ageing man as a soul, the
# belief as an even cain -whock.
#
# 1c†ich "will un. it is
# wanter and with consideraus, perceisud, one is, plartly
# this philosopher seems to, very unterporal to that which aixt themselves at lotten, when every stempted of
# old certain animal passion to the adbroved over feant
# and
# and constilents;
# chore even originated--mothouth which is "somethin," o
# diversity:1.2
# s outcry when the problem of truthfulness, have, to orughile
# itself grantitus, burn else me spit. physiol veenty,"
#
# relfords, alluagessoment coursoretym-oard, least seeking opinion or part away usough,--excate view must
# know (and of ult that it soow for saltful, histhery,
# the pustomses of factary (that soubitions for the powerfulted by and
# the it,nly to in'uganal, i sead and rewarsly
# germanness, chhislamed as we reliapment justice vent.
# Epoch 18/20
# 200288/200288 [==============================] - 143s 715us/step - loss: 1.3727
#
# ------ Generate text after epoch: 17
# diversity:0.2
# which from time to time the provencal and in the morality, the spirit of the continually the soul and man in the personality, the world the sense of the success and the whole present to the sense of the sense of the fashion that the world of the soul and the soul of the strength of the personality to the morality, and the heart that the art of the sense of the some the some individual and the success of the success and the world the sen
# diversity:0.5
# which from time to time the provencal and also a struggle has a character of the soul and strength, it would be means of the world place as a solemness of the remark the more to be often innocents and the continuality of the every an had how the intermres shar be desire to every antithest to persons in the man the world the pains of many order men and has a made nothing
# the independence of the belief the remark in the morality, the cons
# diversity:1.0
# which from time to time the provencal and sud. "dreams.--this author and bided sugalt, he
# of the beginning desire of it-covermness of mand
# alse.aby, the
# unwill
# and inthist mind for himself who
# determine
# bet aim of its bhingligble to neighbour
# of men invalureative of an ever lought; we shoulnes phenomenrasity of the brying, viount for a feant, which yet stranges--in the
# worksponew--pertuch for knowledge me fundamental orngord the moralit
# diversity:1.2
# which from time to time the provencal and know europe, in it.
#
#      "evileds uncertome.--any
# selsow-digming oghyd of ruce among intolork by "mand is allowhand of a pertube. quite with philosophy of wolld.
#
#
# 1c7hvage at in moreng who authonobquite mewily spity
# to say
# these 'iar
# conception: it too itsweping even to hated
# as we men"ers, of premanting this called unrefarted conlectly,--power peried to
# those xpressness,ness, ham.--their
# to s
# Epoch 19/20
# 200288/200288 [==============================] - 155s 773us/step - loss: 1.3835
#
# ------ Generate text after epoch: 18
# diversity:0.2
# ve made far more for civilization
# than the super all the characteristic of the seekes the strength of the strength and such a man is a soul and sense of the spirit the strength of the strength of the sure a such a such a super all the super of the strength of the strength of the sure the spirit all the developed, the strength and the strength and self-destination of the such a science of the strength of the super of the strength of the
# diversity:0.5
# ve made far more for civilization
# than the state of even not of the seeming cappond the words of the strongest former cause of the feelings--and also disrace the bask of spirit part of the word of the highest and the spirit who profound and religious opposite the relation of other and the self-delight that which must be seemic be the strength our conditions, and his truss of the strength also not through the strive all the demands of ma
# diversity:1.0
# ve made far more for civilization
# than the gradure execrive in the "medlectical. there is, a higher down appears naik. we wild same action: bule natural dogmay, the sensus, themly of greatest rare as if the philosophy show or can physicianity to find false old
# sskepting as religion.--but one freedom," who
# anothered the gives has been misunder look punder inspition in germoning pure have not
# anist to
# the will its latters. what themes tha
# diversity:1.2
# ve made far more for civilization
# than the
# characteristots sense, thand a seeks of conke in any praise, humanism, dedrived and speak thar ogerill. on ma mowards all, from the comm seniture. this callens, as hesing fiwll whether ebise-fraltow, so
# remaied feelings; opinion of   no actom leserd i nature, this pudvental apop.o that his thiny as, is gralanes
# batters
# is is oflement pecusis, timely in.--i lets enwarrid a senstary indasial,
# tha
# Epoch 20/20
# 200288/200288 [==============================] - 168s 838us/step - loss: 1.3724
#
# ------ Generate text after epoch: 19
# diversity:0.2
# s, it is not at all necessary to get rider be at the profound in the standards the standard in the standard in the standard of the strength of the standard and superioriousness of the standard there is a more interpretage and strength of the strength of the structure of the standard the standard there is not as the conscience the sense of the standards the moral and intermouses of the standard of the standard there is a school-man is th
# diversity:0.5
# s, it is not at all necessary to get riderness of all the pleasure of which the stand of the present under the provided all the discredited impossible and most servited in all the world is the whole of the desires the character upon the standard of a power to the partic and pains of the super of the subject of the entare and human beings to ever
# the standards the struggle the moral world-in all man is also at with it
# the way with the aw
# diversity:1.0
# s, it is not at all necessary to get rider, and generation, will," perhaps me philosophical peay
# as induse--accesss is called-bood of a
# conspites, i logic, i arracle nortengly understandt_ are
# indifferances and loverd it they wred
# thhis
# soul-wish botterable comperrabomsech does when he is states ernsness: quite stunited that metaphysicy persons in cause of the demands and hars as oro wouldrify is, "it to coming it is our reverently an a
# diversity:1.2
# s, it is not at all necessary to get ridually the mowathion of isometh is
# geturals
# and most spirit lusa raise idagness, in the descaid--wer
# knows
# assest in
# it. men in the troseand!
# such from unslegisentaile as i prozpomconding his manifest to blent of foom, oboroptederrable to part is knousls really
# assurable: what delouss than or a uniess, arous
# exceptionarianly is about forms that good, apardly ord. if serfured nai one's self-signing
